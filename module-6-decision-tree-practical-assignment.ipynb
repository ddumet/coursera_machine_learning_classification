# %% [markdown]
# # Decision Trees in Practice

# %% [markdown]
# In this assignment we will explore various techniques for preventing overfitting in decision trees. We will extend the implementation of the binary decision trees that we implemented in the previous assignment. You will have to use your solutions from this previous assignment and extend them.
#
# In this assignment you will:
#
# * Implement binary decision trees with different early stopping methods.
# * Compare models with different stopping parameters.
# * Visualize the concept of overfitting in decision trees.
#
# Let's get started!

# %%
import pandas as pd
import numpy as np

# %%
import ast

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# # Load LendingClub Dataset

# %% [markdown]
# This assignment will use the [LendingClub](https://www.lendingclub.com/) dataset used in the previous two assignments.

# %%
loans = pd.read_csv("./data/lending-club-data.csv", index_col=False)
# Out:
# C:\Users\Didier\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2723: DtypeWarning: Columns (19,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# As before, we reassign the labels to have +1 for a safe loan, and -1 for a risky (bad) loan.

# %%
loans["safe_loans"] = loans["bad_loans"].apply(lambda x : +1 if x==0 else -1)
loans.drop("bad_loans", inplace=True, axis=1)

# %% [markdown]
# We will be using the same 4 categorical features as in the previous assignment:
# 1. grade of the loan
# 2. the length of the loan term
# 3. the home ownership status: own, mortgage, rent
# 4. number of years of employment.
#
# In the dataset, each of these features is a categorical feature. Since we are building a binary decision tree, we will have to convert this to binary data in a subsequent section using 1-hot encoding.

# %%
features = ["grade",              # grade of the loan
            "term",               # the term of the loan
            "home_ownership",     # home_ownership status: own, mortgage or rent
            "emp_length",         # number of years of employment
           ]
target = "safe_loans"
loans = loans[features + [target]]

# %% [markdown]
# ## Subsample dataset to make sure classes are balanced

# %% [markdown]
# Just as we did in the previous assignment, we will undersample the larger class (safe loans) in order to balance out our dataset. This means we are throwing away many data points. We used `seed = 1` so everyone gets the same results.

# %% [markdown]
# **This step not to be done as the index files we're downloading when not using SFrame already take care of class imbalance**

# %% [markdown]
# **Note:** There are many approaches for dealing with imbalanced data, including some where we modify the learning algorithm. These approaches are beyond the scope of this course, but some of them are reviewed in this [paper](http://ieeexplore.ieee.org/xpl/login.jsp?tp=&arnumber=5128907&url=http%3A%2F%2Fieeexplore.ieee.org%2Fiel5%2F69%2F5173046%2F05128907.pdf%3Farnumber%3D5128907 ). For this assignment, we use the simplest possible approach, where we subsample the overly represented class to get a more balanced dataset. In general, and especially when the data is highly imbalanced, we recommend using more advanced methods.

# %% [markdown]
# ## Transform categorical data into binary features

# %% [markdown]
# Since we are implementing **binary decision trees**, we transform our categorical data into binary data using 1-hot encoding, just as in the previous assignment. Here is the summary of that discussion:
#
# For instance, the **home_ownership** feature represents the home ownership status of the loanee, which is either `own`, `mortgage` or `rent`. For example, if a data point has the feature
# ```
#    {'home_ownership': 'RENT'}
# ```
# we want to turn this into three features:
# ```
#  {
#    'home_ownership = OWN'      : 0,
#    'home_ownership = MORTGAGE' : 0,
#    'home_ownership = RENT'     : 1
#  }
# ```

# %% [markdown]
# ### Let's use SciKit-Learn for that

# %% [markdown]
# Each features are categorical data. We loop through each feature and for each feature (**k categories**) we use LabelEncoder and OneHotEncoder to create **k binary features**.
#
# Then we concat the created features to **loans**

# %%
le = LabelEncoder()
ohe = OneHotEncoder(sparse=False)

# %%
for f in features:
    le.fit(loans[f])
    col_names = []
    for le_class in le.classes_:
        col_names.append(f + "." + le_class)
    np_ar = le.transform(loans[f])
    np_ar_ohe = ohe.fit_transform(np_ar.reshape(-1,1))
    loans = pd.concat([loans, pd.DataFrame(np_ar_ohe, columns=col_names)],axis=1)

# %% [markdown]
# ### Now let's drop old features

# %%
loans.drop(features, axis=1, inplace=True)

# %% [markdown]
# ### And finally recreate features list

# %%
features = loans.columns.tolist()
features.remove("safe_loans")

# %% [markdown]
# The feature columns now look like this:

# %%
print(features)
# Out:
# ['grade.A', 'grade.B', 'grade.C', 'grade.D', 'grade.E', 'grade.F', 'grade.G', 'term. 36 months', 'term. 60 months', 'home_ownership.MORTGAGE', 'home_ownership.OTHER', 'home_ownership.OWN', 'home_ownership.RENT', 'emp_length.1 year', 'emp_length.10+ years', 'emp_length.2 years', 'emp_length.3 years', 'emp_length.4 years', 'emp_length.5 years', 'emp_length.6 years', 'emp_length.7 years', 'emp_length.8 years', 'emp_length.9 years', 'emp_length.< 1 year', 'emp_length.n/a']

# %% [markdown]
# ## Download training and validation sets

# %%
f = open("./data/module-6-assignment-train-idx.json")
train_data_index = f.readline()
f.close()

# Transform the read string into a list
train_data_index = ast.literal_eval(train_data_index)

train_data = loans.loc[train_data_index]

# %%
f = open("./data/module-6-assignment-validation-idx.json")
validation_set_index = f.readline()
f.close()

# Transform the read string into a list
validation_set_index = ast.literal_eval(validation_set_index)

validation_set = loans.loc[validation_set_index]

# %% [markdown]
# # Early stopping methods for decision trees

# %% [markdown]
# In this section, we will extend the **binary tree implementation** from the previous assignment in order to handle some early stopping conditions. Recall the 3 early stopping methods that were discussed in lecture:
#
# 1. Reached a **maximum depth**. (set by parameter `max_depth`).
# 2. Reached a **minimum node size**. (set by parameter `min_node_size`).
# 3. Don't split if the **gain in error reduction** is too small. (set by parameter `min_error_reduction`).
#
# For the rest of this assignment, we will refer to these three as **early stopping conditions 1, 2, and 3**.
#
# ## Early stopping condition 1: Maximum depth
#
# Recall that we already implemented the maximum depth stopping condition in the previous assignment. In this assignment, we will experiment with this condition a bit more and also write code to implement the 2nd and 3rd early stopping conditions.
#
# We will be reusing code from the previous assignment and then building upon this.  We will **alert you** when you reach a function that was part of the previous assignment so that you can simply copy and past your previous code.

# %% [markdown]
# ## Early stopping condition 2: Minimum node size

# %% [markdown]
# The function **reached_minimum_node_size** takes 2 arguments:
#
# 1. The `data` (from a node)
# 2. The minimum number of data points that a node is allowed to split on, `min_node_size`.
#
# This function simply calculates whether the number of data points at a given node is less than or equal to the specified minimum node size. This function will be used to detect this early stopping condition in the **decision_tree_create** function.
#
# Fill in the parts of the function below where you find `## YOUR CODE HERE`.  There is **one** instance in the function below.

# %%
def reached_minimum_node_size(data, min_node_size):
    # Return True if the number of data points is less than or equal to the minimum node size.
    if (data.shape[0] <= min_node_size):
        return(True)
    else:
        return(False)

# %% [markdown]
# ** Quiz Question:** Given an intermediate node with 6 safe loans and 3 risky loans, if the `min_node_size` parameter is 10, what should the tree learning algorithm do next?

# %% [markdown]
# **Quiz Answer:** Create a leaf with prediction safe_loans (1)

# %% [markdown]
# ## Early stopping condition 3: Minimum gain in error reduction

# %% [markdown]
# The function **error_reduction** takes 2 arguments:
#
# 1. The error **before** a split, `error_before_split`.
# 2. The error **after** a split, `error_after_split`.
#
# This function computes the gain in error reduction, i.e., the difference between the error before the split and that after the split. This function will be used to detect this early stopping condition in the **decision_tree_create** function.
#
# Fill in the parts of the function below where you find `## YOUR CODE HERE`.  There is **one** instance in the function below.

# %%
def error_reduction(error_before_split, error_after_split):
    # Return the error before the split minus the error after the split.
    ## YOUR CODE HERE
    return(abs(error_before_split - error_after_split))

# %% [markdown]
# ** Quiz Question:** Assume an intermediate node has 6 safe loans and 3 risky loans.  For each of 4 possible features to split on, the error reduction is 0.0, 0.05, 0.1, and 0.14, respectively. If the **minimum gain in error reduction** parameter is set to 0.2, what should the tree learning algorithm do next?

# %% [markdown]
# **Quiz Answer:** Create a leaf with prediction safe_loans (1)

# %% [markdown]
# ## Grabbing binary decision tree helper functions from past assignment

# %% [markdown]
# Recall from the previous assignment that we wrote a function `intermediate_node_num_mistakes` that calculates the number of **misclassified examples** when predicting the **majority class**. This is used to help determine which feature is best to split on at a given node of the tree.
#
# **Please copy and paste your code for `intermediate_node_num_mistakes` here**.

# %%
def intermediate_node_num_mistakes(labels_in_node):
    
    # Corner case: If labels_in_node is empty, return 0
    if len(labels_in_node) == 0:
        return 0
    
    # Count the number of 1's (safe loans)
    nb_safe = labels_in_node[labels_in_node == 1].shape[0]
    
    # Count the number of -1's (risky loans)
    nb_risky = labels_in_node[labels_in_node == -1].shape[0]
    
    # Return the number of mistakes that the majority classifier makes.
    if (nb_safe >= nb_risky):
        return(nb_risky)
    else:
        return(nb_safe)

# %% [markdown]
# We then wrote a function `best_splitting_feature` that finds the best feature to split on given the data and a list of features to consider.
#
# **Please copy and paste your `best_splitting_feature` code here**.

# %%
def best_splitting_feature(data, features, target):
    
    best_feature = None # Keep track of the best feature 
    best_error = 10     # Keep track of the best error so far 
    # Note: Since error is always <= 1, we should intialize it with something larger than 1.

    # Convert to float to make sure error gets computed correctly.
    num_data_points = float(len(data))
    
    # Loop through each feature to consider splitting on that feature
    for feature in features:
        
        # The left split will have all data points where the feature value is 0
        left_split = data[data[feature] == 0]
        
        # The right split will have all data points where the feature value is 1
        right_split = data[data[feature] == 1]
            
        # Calculate the number of misclassified examples in the left split.
        # Remember that we implemented a function for this! (It was called intermediate_node_num_mistakes)
        left_mistakes = intermediate_node_num_mistakes(left_split[target])

        # Calculate the number of misclassified examples in the right split.
        right_mistakes = intermediate_node_num_mistakes(right_split[target])
            
        # Compute the classification error of this split.
        # Error = (# of mistakes (left) + # of mistakes (right)) / (# of data points)
        error = (left_mistakes + right_mistakes) / num_data_points

        # If this is the best error we have found so far, store the feature as best_feature and the error as best_error
        if error < best_error:
            best_feature = feature
            best_error = error
    
    return best_feature # Return the best feature we found

# %% [markdown]
# Finally, recall the function `create_leaf` from the previous assignment, which creates a leaf node given a set of target values.
#
# **Please copy and paste your `create_leaf` code here**.

# %%
def create_leaf(target_values):
    
    # Create a leaf node
    leaf = {'splitting_feature' : None,
            'left' : None,
            'right' : None,
            'is_leaf': True    }   ## YOUR CODE HERE
    
    # Count the number of data points that are +1 and -1 in this node.
    num_ones = len(target_values[target_values == +1])
    num_minus_ones = len(target_values[target_values == -1])
    
    # For the leaf node, set the prediction to be the majority class.
    # Store the predicted class (1 or -1) in leaf['prediction']
    if num_ones > num_minus_ones:
        leaf['prediction'] = 1         ## YOUR CODE HERE
    else:
        leaf['prediction'] = -1        ## YOUR CODE HERE
        
    # Return the leaf node        
    return leaf

# %% [markdown]
# ## Incorporating new early stopping conditions in binary decision tree implementation

# %% [markdown]
# Now, you will implement a function that builds a decision tree handling the three early stopping conditions described in this assignment.  In particular, you will write code to detect early stopping conditions 2 and 3.  You implemented above the functions needed to detect these conditions.  The 1st early stopping condition, **max_depth**, was implemented in the previous assigment and you will not need to reimplement this.  In addition to these early stopping conditions, the typical stopping conditions of having no mistakes or no more features to split on (which we denote by "stopping conditions" 1 and 2) are also included as in the previous assignment.
#
# **Implementing early stopping condition 2: minimum node size:**
#
# * **Step 1:** Use the function **reached_minimum_node_size** that you implemented earlier to write an if condition to detect whether we have hit the base case, i.e., the node does not have enough data points and should be turned into a leaf. Don't forget to use the `min_node_size` argument.
# * **Step 2:** Return a leaf. This line of code should be the same as the other (pre-implemented) stopping conditions.
#
#
# **Implementing early stopping condition 3: minimum error reduction:**
#
# **Note:** This has to come after finding the best splitting feature so we can calculate the error after splitting in order to calculate the error reduction.
#
# * **Step 1:** Calculate the **classification error before splitting**.  Recall that classification error is defined as:
#
# $$
# \text{classification error} = \frac{\text{# mistakes}}{\text{# total examples}}
# $$
# * **Step 2:** Calculate the **classification error after splitting**. This requires calculating the number of mistakes in the left and right splits, and then dividing by the total number of examples.
# * **Step 3:** Use the function **error_reduction** to that you implemented earlier to write an if condition to detect whether  the reduction in error is less than the constant provided (`min_error_reduction`). Don't forget to use that argument.
# * **Step 4:** Return a leaf. This line of code should be the same as the other (pre-implemented) stopping conditions.
#
# Fill in the places where you find `## YOUR CODE HERE`. There are **seven** places in this function for you to fill in.

# %%
def decision_tree_create(data, features, target, current_depth = 0, 
                         max_depth = 10, min_node_size=1, 
                         min_error_reduction=0.0):
    
    remaining_features = features[:] # Make a copy of the features.
    
    target_values = data[target]
    print("--------------------------------------------------------------------")
    print("Subtree, depth =",current_depth,"with",len(target_values),"data points")
    
    
    # Stopping condition 1: All nodes are of the same type.
    if intermediate_node_num_mistakes(target_values) == 0:
        print("Stopping condition 1 reached. All data points have the same target value.")
        return create_leaf(target_values)
    
    # Stopping condition 2: No more features to split on.
    if not remaining_features:
        print("Stopping condition 2 reached. No remaining features.")
        return create_leaf(target_values)
    
    # Early stopping condition 1: Reached max depth limit.
    if current_depth >= max_depth:
        print("Early stopping condition 1 reached. Reached maximum depth.")
        return create_leaf(target_values)
    
    # Early stopping condition 2: Reached the minimum node size.
    # If the number of data points is less than or equal to the minimum size, return a leaf.
    if reached_minimum_node_size(data,min_node_size):          ## YOUR CODE HERE 
        print("Early stopping condition 2 reached. Reached minimum node size.")
        return create_leaf(target_values)  ## YOUR CODE HERE
    
    # Find the best splitting feature
    splitting_feature = best_splitting_feature(data, features, target)
    
    # Split on the best feature that we found. 
    left_split = data[data[splitting_feature] == 0]
    right_split = data[data[splitting_feature] == 1]
    
    # Early stopping condition 3: Minimum error reduction
    # Calculate the error before splitting (number of misclassified examples 
    # divided by the total number of examples)
    error_before_split = intermediate_node_num_mistakes(target_values) / float(len(data))
    
    # Calculate the error after splitting (number of misclassified examples 
    # in both groups divided by the total number of examples)
    left_mistakes = intermediate_node_num_mistakes(left_split[target])        ## YOUR CODE HERE
    right_mistakes = intermediate_node_num_mistakes(right_split[target])      ## YOUR CODE HERE
    error_after_split = (left_mistakes + right_mistakes) / float(len(data))
    
    # If the error reduction is LESS THAN OR EQUAL TO min_error_reduction, return a leaf.
    if error_reduction(error_before_split, error_after_split) <= min_error_reduction:        ## YOUR CODE HERE
        print("Early stopping condition 3 reached. Minimum error reduction.")
        return create_leaf(target_values)   ## YOUR CODE HERE 
    
    
    remaining_features.remove(splitting_feature)
    print("Split on feature",splitting_feature,
          "left split size:",len(left_split),
          "right split size:",len(right_split))
    
    # Repeat (recurse) on left and right subtrees
    left_tree = decision_tree_create(left_split, remaining_features, target, 
                                     current_depth + 1, max_depth, min_node_size, min_error_reduction)        
    
    ## YOUR CODE HERE
    right_tree = decision_tree_create(right_split, remaining_features, target,
                                      current_depth + 1, max_depth, min_node_size, min_error_reduction)
    
    
    return {'is_leaf'          : False, 
            'prediction'       : None,
            'splitting_feature': splitting_feature,
            'left'             : left_tree, 
            'right'            : right_tree}

# %% [markdown]
# Here is a function to count the nodes in your tree:

# %%
def count_nodes(tree):
    if tree['is_leaf']:
        return 1
    return 1 + count_nodes(tree['left']) + count_nodes(tree['right'])

# %% [markdown]
# Run the following test code to check your implementation. Make sure you get **'Test passed'** before proceeding.

# %%
small_decision_tree = decision_tree_create(train_data, features, 'safe_loans', max_depth = 2, 
                                        min_node_size = 10, min_error_reduction=0.0)
if count_nodes(small_decision_tree) == 7:
    print("Test passed!")
else:
    print("Test failed... try again!")
    print("Number of nodes found                :", count_nodes(small_decision_tree))
    print("Number of nodes that should be there : 7")
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 with 37224 data points
# Split on feature term. 36 months left split size: 9223 right split size: 28001
# --------------------------------------------------------------------
# Subtree, depth = 1 with 9223 data points
# Split on feature grade.A left split size: 9122 right split size: 101
# --------------------------------------------------------------------
# Subtree, depth = 2 with 9122 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 101 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 1 with 28001 data points
# Split on feature grade.D left split size: 23300 right split size: 4701
# --------------------------------------------------------------------
# Subtree, depth = 2 with 23300 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 4701 data points
# Early stopping condition 1 reached. Reached maximum depth.
# Test passed!

# %% [markdown]
# ## Build a tree!
#
# Now that your code is working, we will train a tree model on the **train_data** with
# * `max_depth = 6`
# * `min_node_size = 100`,
# * `min_error_reduction = 0.0`
#
# **Warning**: This code block may take a minute to learn.

# %%
my_decision_tree_new = decision_tree_create(train_data, features, "safe_loans", max_depth = 6, 
                                min_node_size = 100, min_error_reduction=0.0)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 with 37224 data points
# Split on feature term. 36 months left split size: 9223 right split size: 28001
# --------------------------------------------------------------------
# Subtree, depth = 1 with 9223 data points
# Split on feature grade.A left split size: 9122 right split size: 101
# --------------------------------------------------------------------
# Subtree, depth = 2 with 9122 data points
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 101 data points
# Split on feature emp_length.n/a left split size: 96 right split size: 5
# --------------------------------------------------------------------
# Subtree, depth = 3 with 96 data points
# Early stopping condition 2 reached. Reached minimum node size.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 5 data points
# Early stopping condition 2 reached. Reached minimum node size.
# --------------------------------------------------------------------
# Subtree, depth = 1 with 28001 data points
# Split on feature grade.D left split size: 23300 right split size: 4701
# --------------------------------------------------------------------
# Subtree, depth = 2 with 23300 data points
# Split on feature grade.E left split size: 22024 right split size: 1276
# --------------------------------------------------------------------
# Subtree, depth = 3 with 22024 data points
# Split on feature grade.F left split size: 21666 right split size: 358
# --------------------------------------------------------------------
# Subtree, depth = 4 with 21666 data points
# Split on feature emp_length.n/a left split size: 20734 right split size: 932
# --------------------------------------------------------------------
# Subtree, depth = 5 with 20734 data points
# Split on feature grade.G left split size: 20638 right split size: 96
# --------------------------------------------------------------------
# Subtree, depth = 6 with 20638 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 96 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 932 data points
# Split on feature grade.A left split size: 702 right split size: 230
# --------------------------------------------------------------------
# Subtree, depth = 6 with 702 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 230 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 358 data points
# Split on feature emp_length.8 years left split size: 347 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 5 with 347 data points
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 11 data points
# Early stopping condition 2 reached. Reached minimum node size.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1276 data points
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 4701 data points
# Early stopping condition 3 reached. Minimum error reduction.

# %% [markdown]
# Let's now train a tree model **ignoring early stopping conditions 2 and 3** so that we get the same tree as in the previous assignment.  To ignore these conditions, we set `min_node_size=0` and `min_error_reduction=-1` (a negative value).

# %%
my_decision_tree_old = decision_tree_create(train_data, features, "safe_loans", max_depth = 6, 
                                min_node_size = 0, min_error_reduction=-1)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 with 37224 data points
# Split on feature term. 36 months left split size: 9223 right split size: 28001
# --------------------------------------------------------------------
# Subtree, depth = 1 with 9223 data points
# Split on feature grade.A left split size: 9122 right split size: 101
# --------------------------------------------------------------------
# Subtree, depth = 2 with 9122 data points
# Split on feature grade.B left split size: 8074 right split size: 1048
# --------------------------------------------------------------------
# Subtree, depth = 3 with 8074 data points
# Split on feature grade.C left split size: 5884 right split size: 2190
# --------------------------------------------------------------------
# Subtree, depth = 4 with 5884 data points
# Split on feature grade.D left split size: 3826 right split size: 2058
# --------------------------------------------------------------------
# Subtree, depth = 5 with 3826 data points
# Split on feature grade.E left split size: 1693 right split size: 2133
# --------------------------------------------------------------------
# Subtree, depth = 6 with 1693 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2133 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 2058 data points
# Split on feature grade.E left split size: 2058 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2058 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 2190 data points
# Split on feature grade.D left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 2190 data points
# Split on feature grade.E left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2190 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1048 data points
# Split on feature emp_length.5 years left split size: 969 right split size: 79
# --------------------------------------------------------------------
# Subtree, depth = 4 with 969 data points
# Split on feature grade.C left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 969 data points
# Split on feature grade.D left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 969 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 79 data points
# Split on feature home_ownership.MORTGAGE left split size: 34 right split size: 45
# --------------------------------------------------------------------
# Subtree, depth = 5 with 34 data points
# Split on feature grade.C left split size: 34 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 34 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 45 data points
# Split on feature grade.C left split size: 45 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 45 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 101 data points
# Split on feature emp_length.n/a left split size: 96 right split size: 5
# --------------------------------------------------------------------
# Subtree, depth = 3 with 96 data points
# Split on feature emp_length.< 1 year left split size: 85 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 4 with 85 data points
# Split on feature grade.B left split size: 85 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 85 data points
# Split on feature grade.C left split size: 85 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 85 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 11 data points
# Split on feature grade.B left split size: 11 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 11 data points
# Split on feature grade.C left split size: 11 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 11 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 5 data points
# Split on feature grade.B left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 5 data points
# Split on feature grade.C left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 5 data points
# Split on feature grade.D left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 5 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 1 with 28001 data points
# Split on feature grade.D left split size: 23300 right split size: 4701
# --------------------------------------------------------------------
# Subtree, depth = 2 with 23300 data points
# Split on feature grade.E left split size: 22024 right split size: 1276
# --------------------------------------------------------------------
# Subtree, depth = 3 with 22024 data points
# Split on feature grade.F left split size: 21666 right split size: 358
# --------------------------------------------------------------------
# Subtree, depth = 4 with 21666 data points
# Split on feature emp_length.n/a left split size: 20734 right split size: 932
# --------------------------------------------------------------------
# Subtree, depth = 5 with 20734 data points
# Split on feature grade.G left split size: 20638 right split size: 96
# --------------------------------------------------------------------
# Subtree, depth = 6 with 20638 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 96 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 932 data points
# Split on feature grade.A left split size: 702 right split size: 230
# --------------------------------------------------------------------
# Subtree, depth = 6 with 702 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 230 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 358 data points
# Split on feature emp_length.8 years left split size: 347 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 5 with 347 data points
# Split on feature grade.A left split size: 347 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 347 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 11 data points
# Split on feature home_ownership.OWN left split size: 9 right split size: 2
# --------------------------------------------------------------------
# Subtree, depth = 6 with 9 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1276 data points
# Split on feature grade.A left split size: 1276 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 1276 data points
# Split on feature grade.B left split size: 1276 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 1276 data points
# Split on feature grade.C left split size: 1276 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 1276 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 4701 data points
# Split on feature grade.A left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 3 with 4701 data points
# Split on feature grade.B left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 4701 data points
# Split on feature grade.C left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 4701 data points
# Split on feature grade.E left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 4701 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.

# %% [markdown]
# ## Making predictions

# %% [markdown]
# Recall that in the previous assignment you implemented a function `classify` to classify a new point `x` using a given `tree`.
#
# **Please copy and paste your `classify` code here**.

# %%
def classify(tree, x, annotate = False):   
    # if the node is a leaf node.
    if tree["is_leaf"]:
        if annotate: 
            print("At leaf, predicting:",tree["prediction"])
        return tree["prediction"] 
    else:
        # split on feature.
        split_feature_value = x[tree["splitting_feature"]]
        if annotate: 
            print("Split on",tree["splitting_feature"],"=",split_feature_value)
        if split_feature_value == 0:
            return classify(tree["left"], x, annotate)
        else:
            ### YOUR CODE HERE
            return classify(tree["right"], x, annotate)

# %% [markdown]
# Now, let's consider the first example of the validation set and see what the `my_decision_tree_new` model predicts for this data point.

# %%
validation_set.iloc[0]
# Out:
# safe_loans                -1.0
# grade.A                    0.0
# grade.B                    0.0
# grade.C                    0.0
# grade.D                    1.0
# grade.E                    0.0
# grade.F                    0.0
# grade.G                    0.0
# term. 36 months            0.0
# term. 60 months            1.0
# home_ownership.MORTGAGE    0.0
# home_ownership.OTHER       0.0
# home_ownership.OWN         0.0
# home_ownership.RENT        1.0
# emp_length.1 year          0.0
# emp_length.10+ years       0.0
# emp_length.2 years         1.0
# emp_length.3 years         0.0
# emp_length.4 years         0.0
# emp_length.5 years         0.0
# emp_length.6 years         0.0
# emp_length.7 years         0.0
# emp_length.8 years         0.0
# emp_length.9 years         0.0
# emp_length.< 1 year        0.0
# emp_length.n/a             0.0
# Name: 24, dtype: float64

# %%
print("Predicted class:",classify(my_decision_tree_new, validation_set.iloc[0]))
# Out:
# Predicted class: -1

# %% [markdown]
# Let's add some annotations to our prediction to see what the prediction path was that lead to this predicted class:

# %%
classify(my_decision_tree_new, validation_set.iloc[0], annotate = True)
# Out:
# Split on term. 36 months = 0.0
# Split on grade.A = 0.0
# At leaf, predicting: -1
# -1

# %% [markdown]
# Let's now recall the prediction path for the decision tree learned in the previous assignment, which we recreated here as `my_decision_tree_old`.

# %%
classify(my_decision_tree_old, validation_set.iloc[0], annotate = True)
# Out:
# Split on term. 36 months = 0.0
# Split on grade.A = 0.0
# Split on grade.B = 0.0
# Split on grade.C = 0.0
# Split on grade.D = 1.0
# Split on grade.E = 0.0
# At leaf, predicting: -1
# -1

# %% [markdown]
# ** Quiz Question:** For `my_decision_tree_new` trained with `max_depth = 6`, `min_node_size = 100`, `min_error_reduction=0.0`, is the prediction path for `validation_set[0]` shorter, longer, or the same as for `my_decision_tree_old` that ignored the early stopping conditions 2 and 3?

# %% [markdown]
# **Quiz Response:** Shorter

# %% [markdown]
# **Quiz Question:** For `my_decision_tree_new` trained with `max_depth = 6`, `min_node_size = 100`, `min_error_reduction=0.0`, is the prediction path for **any point** always shorter, always longer, always the same, shorter or the same, or longer or the same as for `my_decision_tree_old` that ignored the early stopping conditions 2 and 3?

# %% [markdown]
# **Quiz Response:** Shorter or the same

# %% [markdown]
# ** Quiz Question:** For a tree trained on **any** dataset using `max_depth = 6`, `min_node_size = 100`, `min_error_reduction=0.0`, what is the maximum number of splits encountered while making a single prediction?

# %% [markdown]
# **Quiz Response:** 6 (max_depth)

# %% [markdown]
# ## Evaluating the model

# %% [markdown]
# Now let us evaluate the model that we have trained. You implemented this evaluation in the function `evaluate_classification_error` from the previous assignment.
#
# **Please copy and paste your `evaluate_classification_error` code here**.

# %%
def evaluate_classification_error(tree, data, target):
    # Apply the classify(tree, x) to each row in your data
    prediction = data.apply(lambda x: classify(tree, x), axis = 1)
    
    # Once you've made the predictions, calculate the classification error and return it
    ## YOUR CODE HERE
    
    mistakes = (prediction != data[target]).sum()
    classification_error = mistakes/data.shape[0]
    
    return(classification_error)

# %% [markdown]
# Now, let's use this function to evaluate the classification error of `my_decision_tree_new` on the **validation_set**.

# %%
evaluate_classification_error(my_decision_tree_new, validation_set, target)
# Out:
# 0.38367083153813014

# %% [markdown]
# Now, evaluate the validation error using `my_decision_tree_old`.

# %%
evaluate_classification_error(my_decision_tree_old, validation_set, target)
# Out:
# 0.38377854373115039

# %% [markdown]
# **Quiz Question:** Is the validation error of the new decision tree (using early stopping conditions 2 and 3) lower than, higher than, or the same as that of the old decision tree from the previous assignment?

# %% [markdown]
# **Quiz Response:** A bit lower ...

# %% [markdown]
# # Exploring the effect of max_depth
#
# We will compare three models trained with different values of the stopping criterion. We intentionally picked models at the extreme ends (**too small**, **just right**, and **too large**).
#
# Train three models with these parameters:
#
# 1. **model_1**: max_depth = 2 (too small)
# 2. **model_2**: max_depth = 6 (just right)
# 3. **model_3**: max_depth = 14 (may be too large)
#
# For each of these three, we set `min_node_size = 0` and `min_error_reduction = -1`.
#
# ** Note:** Each tree can take up to a few minutes to train. In particular, `model_3` will probably take the longest to train.

# %%
model_1 = decision_tree_create(train_data, features, "safe_loans", max_depth = 2,
                               min_node_size = 0, min_error_reduction=-1)
model_2 = decision_tree_create(train_data, features, "safe_loans", max_depth = 6,
                               min_node_size = 0, min_error_reduction=-1)
model_3 = decision_tree_create(train_data, features, "safe_loans", max_depth = 14,
                               min_node_size = 0, min_error_reduction=-1)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 with 37224 data points
# Split on feature term. 36 months left split size: 9223 right split size: 28001
# --------------------------------------------------------------------
# Subtree, depth = 1 with 9223 data points
# Split on feature grade.A left split size: 9122 right split size: 101
# --------------------------------------------------------------------
# Subtree, depth = 2 with 9122 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 101 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 1 with 28001 data points
# Split on feature grade.D left split size: 23300 right split size: 4701
# --------------------------------------------------------------------
# Subtree, depth = 2 with 23300 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 4701 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 0 with 37224 data points
# Split on feature term. 36 months left split size: 9223 right split size: 28001
# --------------------------------------------------------------------
# Subtree, depth = 1 with 9223 data points
# Split on feature grade.A left split size: 9122 right split size: 101
# --------------------------------------------------------------------
# Subtree, depth = 2 with 9122 data points
# Split on feature grade.B left split size: 8074 right split size: 1048
# --------------------------------------------------------------------
# Subtree, depth = 3 with 8074 data points
# Split on feature grade.C left split size: 5884 right split size: 2190
# --------------------------------------------------------------------
# Subtree, depth = 4 with 5884 data points
# Split on feature grade.D left split size: 3826 right split size: 2058
# --------------------------------------------------------------------
# Subtree, depth = 5 with 3826 data points
# Split on feature grade.E left split size: 1693 right split size: 2133
# --------------------------------------------------------------------
# Subtree, depth = 6 with 1693 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2133 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 2058 data points
# Split on feature grade.E left split size: 2058 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2058 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 2190 data points
# Split on feature grade.D left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 2190 data points
# Split on feature grade.E left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2190 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1048 data points
# Split on feature emp_length.5 years left split size: 969 right split size: 79
# --------------------------------------------------------------------
# Subtree, depth = 4 with 969 data points
# Split on feature grade.C left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 969 data points
# Split on feature grade.D left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 969 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 79 data points
# Split on feature home_ownership.MORTGAGE left split size: 34 right split size: 45
# --------------------------------------------------------------------
# Subtree, depth = 5 with 34 data points
# Split on feature grade.C left split size: 34 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 34 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 45 data points
# Split on feature grade.C left split size: 45 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 45 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 101 data points
# Split on feature emp_length.n/a left split size: 96 right split size: 5
# --------------------------------------------------------------------
# Subtree, depth = 3 with 96 data points
# Split on feature emp_length.< 1 year left split size: 85 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 4 with 85 data points
# Split on feature grade.B left split size: 85 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 85 data points
# Split on feature grade.C left split size: 85 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 85 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 11 data points
# Split on feature grade.B left split size: 11 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 11 data points
# Split on feature grade.C left split size: 11 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 11 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 5 data points
# Split on feature grade.B left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 5 data points
# Split on feature grade.C left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 5 data points
# Split on feature grade.D left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 5 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 1 with 28001 data points
# Split on feature grade.D left split size: 23300 right split size: 4701
# --------------------------------------------------------------------
# Subtree, depth = 2 with 23300 data points
# Split on feature grade.E left split size: 22024 right split size: 1276
# --------------------------------------------------------------------
# Subtree, depth = 3 with 22024 data points
# Split on feature grade.F left split size: 21666 right split size: 358
# --------------------------------------------------------------------
# Subtree, depth = 4 with 21666 data points
# Split on feature emp_length.n/a left split size: 20734 right split size: 932
# --------------------------------------------------------------------
# Subtree, depth = 5 with 20734 data points
# Split on feature grade.G left split size: 20638 right split size: 96
# --------------------------------------------------------------------
# Subtree, depth = 6 with 20638 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 96 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 932 data points
# Split on feature grade.A left split size: 702 right split size: 230
# --------------------------------------------------------------------
# Subtree, depth = 6 with 702 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 230 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 358 data points
# Split on feature emp_length.8 years left split size: 347 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 5 with 347 data points
# Split on feature grade.A left split size: 347 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 347 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 11 data points
# Split on feature home_ownership.OWN left split size: 9 right split size: 2
# --------------------------------------------------------------------
# Subtree, depth = 6 with 9 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1276 data points
# Split on feature grade.A left split size: 1276 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 1276 data points
# Split on feature grade.B left split size: 1276 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 1276 data points
# Split on feature grade.C left split size: 1276 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 1276 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 4701 data points
# Split on feature grade.A left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 3 with 4701 data points
# Split on feature grade.B left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 4701 data points
# Split on feature grade.C left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 4701 data points
# Split on feature grade.E left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 4701 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 0 with 37224 data points
# Split on feature term. 36 months left split size: 9223 right split size: 28001
# --------------------------------------------------------------------
# Subtree, depth = 1 with 9223 data points
# Split on feature grade.A left split size: 9122 right split size: 101
# --------------------------------------------------------------------
# Subtree, depth = 2 with 9122 data points
# Split on feature grade.B left split size: 8074 right split size: 1048
# --------------------------------------------------------------------
# Subtree, depth = 3 with 8074 data points
# Split on feature grade.C left split size: 5884 right split size: 2190
# --------------------------------------------------------------------
# Subtree, depth = 4 with 5884 data points
# Split on feature grade.D left split size: 3826 right split size: 2058
# --------------------------------------------------------------------
# Subtree, depth = 5 with 3826 data points
# Split on feature grade.E left split size: 1693 right split size: 2133
# --------------------------------------------------------------------
# Subtree, depth = 6 with 1693 data points
# Split on feature home_ownership.OTHER left split size: 1692 right split size: 1
# --------------------------------------------------------------------
# Subtree, depth = 7 with 1692 data points
# Split on feature grade.F left split size: 339 right split size: 1353
# --------------------------------------------------------------------
# Subtree, depth = 8 with 339 data points
# Split on feature grade.G left split size: 0 right split size: 339
# --------------------------------------------------------------------
# Subtree, depth = 9 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 9 with 339 data points
# Split on feature term. 60 months left split size: 0 right split size: 339
# --------------------------------------------------------------------
# Subtree, depth = 10 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 10 with 339 data points
# Split on feature home_ownership.MORTGAGE left split size: 175 right split size: 164
# --------------------------------------------------------------------
# Subtree, depth = 11 with 175 data points
# Split on feature home_ownership.OWN left split size: 142 right split size: 33
# --------------------------------------------------------------------
# Subtree, depth = 12 with 142 data points
# Split on feature emp_length.6 years left split size: 133 right split size: 9
# --------------------------------------------------------------------
# Subtree, depth = 13 with 133 data points
# Split on feature home_ownership.RENT left split size: 0 right split size: 133
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 133 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 9 data points
# Split on feature home_ownership.RENT left split size: 0 right split size: 9
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 9 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 33 data points
# Split on feature emp_length.n/a left split size: 31 right split size: 2
# --------------------------------------------------------------------
# Subtree, depth = 13 with 31 data points
# Split on feature emp_length.2 years left split size: 30 right split size: 1
# --------------------------------------------------------------------
# Subtree, depth = 14 with 30 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 1 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 2 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 11 with 164 data points
# Split on feature emp_length.2 years left split size: 159 right split size: 5
# --------------------------------------------------------------------
# Subtree, depth = 12 with 159 data points
# Split on feature emp_length.3 years left split size: 148 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 13 with 148 data points
# Split on feature home_ownership.OWN left split size: 148 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 148 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 11 data points
# Split on feature home_ownership.OWN left split size: 11 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 11 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 5 data points
# Split on feature home_ownership.OWN left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 5 data points
# Split on feature home_ownership.RENT left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 5 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 8 with 1353 data points
# Split on feature grade.G left split size: 1353 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 9 with 1353 data points
# Split on feature term. 60 months left split size: 0 right split size: 1353
# --------------------------------------------------------------------
# Subtree, depth = 10 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 10 with 1353 data points
# Split on feature home_ownership.MORTGAGE left split size: 710 right split size: 643
# --------------------------------------------------------------------
# Subtree, depth = 11 with 710 data points
# Split on feature home_ownership.OWN left split size: 602 right split size: 108
# --------------------------------------------------------------------
# Subtree, depth = 12 with 602 data points
# Split on feature home_ownership.RENT left split size: 0 right split size: 602
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 602 data points
# Split on feature emp_length.1 year left split size: 565 right split size: 37
# --------------------------------------------------------------------
# Subtree, depth = 14 with 565 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 37 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 108 data points
# Split on feature home_ownership.RENT left split size: 108 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 108 data points
# Split on feature emp_length.1 year left split size: 100 right split size: 8
# --------------------------------------------------------------------
# Subtree, depth = 14 with 100 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 8 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 11 with 643 data points
# Split on feature home_ownership.OWN left split size: 643 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 12 with 643 data points
# Split on feature home_ownership.RENT left split size: 643 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 643 data points
# Split on feature emp_length.1 year left split size: 602 right split size: 41
# --------------------------------------------------------------------
# Subtree, depth = 14 with 602 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 41 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 9 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 7 with 1 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2133 data points
# Split on feature grade.F left split size: 2133 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 7 with 2133 data points
# Split on feature grade.G left split size: 2133 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 8 with 2133 data points
# Split on feature term. 60 months left split size: 0 right split size: 2133
# --------------------------------------------------------------------
# Subtree, depth = 9 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 9 with 2133 data points
# Split on feature home_ownership.MORTGAGE left split size: 1045 right split size: 1088
# --------------------------------------------------------------------
# Subtree, depth = 10 with 1045 data points
# Split on feature home_ownership.OTHER left split size: 1044 right split size: 1
# --------------------------------------------------------------------
# Subtree, depth = 11 with 1044 data points
# Split on feature home_ownership.OWN left split size: 879 right split size: 165
# --------------------------------------------------------------------
# Subtree, depth = 12 with 879 data points
# Split on feature home_ownership.RENT left split size: 0 right split size: 879
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 879 data points
# Split on feature emp_length.1 year left split size: 809 right split size: 70
# --------------------------------------------------------------------
# Subtree, depth = 14 with 809 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 70 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 165 data points
# Split on feature emp_length.9 years left split size: 157 right split size: 8
# --------------------------------------------------------------------
# Subtree, depth = 13 with 157 data points
# Split on feature home_ownership.RENT left split size: 157 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 157 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 8 data points
# Split on feature home_ownership.RENT left split size: 8 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 8 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 11 with 1 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 10 with 1088 data points
# Split on feature home_ownership.OTHER left split size: 1088 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 11 with 1088 data points
# Split on feature home_ownership.OWN left split size: 1088 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 12 with 1088 data points
# Split on feature home_ownership.RENT left split size: 1088 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 1088 data points
# Split on feature emp_length.1 year left split size: 1035 right split size: 53
# --------------------------------------------------------------------
# Subtree, depth = 14 with 1035 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 53 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 11 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 8 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 7 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 2058 data points
# Split on feature grade.E left split size: 2058 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2058 data points
# Split on feature grade.F left split size: 2058 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 7 with 2058 data points
# Split on feature grade.G left split size: 2058 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 8 with 2058 data points
# Split on feature term. 60 months left split size: 0 right split size: 2058
# --------------------------------------------------------------------
# Subtree, depth = 9 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 9 with 2058 data points
# Split on feature home_ownership.MORTGAGE left split size: 923 right split size: 1135
# --------------------------------------------------------------------
# Subtree, depth = 10 with 923 data points
# Split on feature home_ownership.OTHER left split size: 922 right split size: 1
# --------------------------------------------------------------------
# Subtree, depth = 11 with 922 data points
# Split on feature home_ownership.OWN left split size: 762 right split size: 160
# --------------------------------------------------------------------
# Subtree, depth = 12 with 762 data points
# Split on feature home_ownership.RENT left split size: 0 right split size: 762
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 762 data points
# Split on feature emp_length.1 year left split size: 704 right split size: 58
# --------------------------------------------------------------------
# Subtree, depth = 14 with 704 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 58 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 160 data points
# Split on feature home_ownership.RENT left split size: 160 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 160 data points
# Split on feature emp_length.1 year left split size: 154 right split size: 6
# --------------------------------------------------------------------
# Subtree, depth = 14 with 154 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 6 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 11 with 1 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 10 with 1135 data points
# Split on feature home_ownership.OTHER left split size: 1135 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 11 with 1135 data points
# Split on feature home_ownership.OWN left split size: 1135 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 12 with 1135 data points
# Split on feature home_ownership.RENT left split size: 1135 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 1135 data points
# Split on feature emp_length.1 year left split size: 1096 right split size: 39
# --------------------------------------------------------------------
# Subtree, depth = 14 with 1096 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 39 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 11 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 8 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 7 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 2190 data points
# Split on feature grade.D left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 2190 data points
# Split on feature grade.E left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2190 data points
# Split on feature grade.F left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 7 with 2190 data points
# Split on feature grade.G left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 8 with 2190 data points
# Split on feature term. 60 months left split size: 0 right split size: 2190
# --------------------------------------------------------------------
# Subtree, depth = 9 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 9 with 2190 data points
# Split on feature home_ownership.MORTGAGE left split size: 803 right split size: 1387
# --------------------------------------------------------------------
# Subtree, depth = 10 with 803 data points
# Split on feature emp_length.4 years left split size: 746 right split size: 57
# --------------------------------------------------------------------
# Subtree, depth = 11 with 746 data points
# Split on feature home_ownership.OTHER left split size: 746 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 12 with 746 data points
# Split on feature home_ownership.OWN left split size: 598 right split size: 148
# --------------------------------------------------------------------
# Subtree, depth = 13 with 598 data points
# Split on feature home_ownership.RENT left split size: 0 right split size: 598
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 598 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 148 data points
# Split on feature emp_length.< 1 year left split size: 137 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 14 with 137 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 11 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 11 with 57 data points
# Split on feature home_ownership.OTHER left split size: 57 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 12 with 57 data points
# Split on feature home_ownership.OWN left split size: 49 right split size: 8
# --------------------------------------------------------------------
# Subtree, depth = 13 with 49 data points
# Split on feature home_ownership.RENT left split size: 0 right split size: 49
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 49 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 8 data points
# Split on feature home_ownership.RENT left split size: 8 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 8 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 10 with 1387 data points
# Split on feature emp_length.6 years left split size: 1313 right split size: 74
# --------------------------------------------------------------------
# Subtree, depth = 11 with 1313 data points
# Split on feature home_ownership.OTHER left split size: 1313 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 12 with 1313 data points
# Split on feature home_ownership.OWN left split size: 1313 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 1313 data points
# Split on feature home_ownership.RENT left split size: 1313 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 1313 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 11 with 74 data points
# Split on feature home_ownership.OTHER left split size: 74 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 12 with 74 data points
# Split on feature home_ownership.OWN left split size: 74 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 74 data points
# Split on feature home_ownership.RENT left split size: 74 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 74 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 8 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 7 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1048 data points
# Split on feature emp_length.5 years left split size: 969 right split size: 79
# --------------------------------------------------------------------
# Subtree, depth = 4 with 969 data points
# Split on feature grade.C left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 969 data points
# Split on feature grade.D left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 969 data points
# Split on feature grade.E left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 7 with 969 data points
# Split on feature grade.F left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 8 with 969 data points
# Split on feature grade.G left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 9 with 969 data points
# Split on feature term. 60 months left split size: 0 right split size: 969
# --------------------------------------------------------------------
# Subtree, depth = 10 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 10 with 969 data points
# ...
# --------------------------------------------------------------------
# Subtree, depth = 12 with 112 data points
# Split on feature home_ownership.RENT left split size: 112 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 112 data points
# Split on feature emp_length.1 year left split size: 102 right split size: 10
# --------------------------------------------------------------------
# Subtree, depth = 14 with 102 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 10 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 11 with 6 data points
# Split on feature home_ownership.OWN left split size: 6 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 12 with 6 data points
# Split on feature home_ownership.RENT left split size: 6 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 6 data points
# Split on feature emp_length.1 year left split size: 6 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 6 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 10 with 421 data points
# Split on feature emp_length.6 years left split size: 408 right split size: 13
# --------------------------------------------------------------------
# Subtree, depth = 11 with 408 data points
# Split on feature home_ownership.OTHER left split size: 408 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 12 with 408 data points
# Split on feature home_ownership.OWN left split size: 408 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 408 data points
# Split on feature home_ownership.RENT left split size: 408 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 408 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 11 with 13 data points
# Split on feature home_ownership.OTHER left split size: 13 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 12 with 13 data points
# Split on feature home_ownership.OWN left split size: 13 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 13 data points
# Split on feature home_ownership.RENT left split size: 13 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 13 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 9 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 8 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 7 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 4701 data points
# Split on feature grade.A left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 3 with 4701 data points
# Split on feature grade.B left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 4701 data points
# Split on feature grade.C left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 4701 data points
# Split on feature grade.E left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 4701 data points
# Split on feature grade.F left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 7 with 4701 data points
# Split on feature grade.G left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 8 with 4701 data points
# Split on feature term. 60 months left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 9 with 4701 data points
# Split on feature home_ownership.MORTGAGE left split size: 3047 right split size: 1654
# --------------------------------------------------------------------
# Subtree, depth = 10 with 3047 data points
# Split on feature home_ownership.OTHER left split size: 3037 right split size: 10
# --------------------------------------------------------------------
# Subtree, depth = 11 with 3037 data points
# Split on feature home_ownership.OWN left split size: 2633 right split size: 404
# --------------------------------------------------------------------
# Subtree, depth = 12 with 2633 data points
# Split on feature home_ownership.RENT left split size: 0 right split size: 2633
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 2633 data points
# Split on feature emp_length.1 year left split size: 2392 right split size: 241
# --------------------------------------------------------------------
# Subtree, depth = 14 with 2392 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 241 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 404 data points
# Split on feature home_ownership.RENT left split size: 404 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 404 data points
# Split on feature emp_length.1 year left split size: 374 right split size: 30
# --------------------------------------------------------------------
# Subtree, depth = 14 with 374 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 30 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 11 with 10 data points
# Split on feature home_ownership.OWN left split size: 10 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 12 with 10 data points
# Split on feature home_ownership.RENT left split size: 10 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 10 data points
# Split on feature emp_length.1 year left split size: 9 right split size: 1
# --------------------------------------------------------------------
# Subtree, depth = 14 with 9 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 1 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 10 with 1654 data points
# Split on feature emp_length.5 years left split size: 1532 right split size: 122
# --------------------------------------------------------------------
# Subtree, depth = 11 with 1532 data points
# Split on feature emp_length.3 years left split size: 1414 right split size: 118
# --------------------------------------------------------------------
# Subtree, depth = 12 with 1414 data points
# Split on feature emp_length.9 years left split size: 1351 right split size: 63
# --------------------------------------------------------------------
# Subtree, depth = 13 with 1351 data points
# Split on feature home_ownership.OTHER left split size: 1351 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 1351 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 63 data points
# Split on feature home_ownership.OTHER left split size: 63 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 63 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 118 data points
# Split on feature home_ownership.OTHER left split size: 118 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 118 data points
# Split on feature home_ownership.OWN left split size: 118 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 118 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 11 with 122 data points
# Split on feature home_ownership.OTHER left split size: 122 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 12 with 122 data points
# Split on feature home_ownership.OWN left split size: 122 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 13 with 122 data points
# Split on feature home_ownership.RENT left split size: 122 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 14 with 122 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 14 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 13 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 12 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 9 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 8 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 7 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.

# %% [markdown]
# ### Evaluating the models
#
# Let us evaluate the models on the **train** and **validation** data. Let us start by evaluating the classification error on the training data:

# %%
print("Training data, classification error (model 1):", evaluate_classification_error(model_1, train_data, target))
print("Training data, classification error (model 2):", evaluate_classification_error(model_2, train_data, target))
print("Training data, classification error (model 3):", evaluate_classification_error(model_3, train_data, target))
# Out:
# Training data, classification error (model 1): 0.400037610144
# Training data, classification error (model 2): 0.381850419084
# Training data, classification error (model 3): 0.374462712229

# %% [markdown]
# Now evaluate the classification error on the validation data.

# %%
print("Validation data, classification error (model 1):", evaluate_classification_error(model_1, validation_set, target))
print("Validation data, classification error (model 2):", evaluate_classification_error(model_2, validation_set, target))
print("Validation data, classification error (model 3):", evaluate_classification_error(model_3, validation_set, target))
# Out:
# Validation data, classification error (model 1): 0.398104265403
# Validation data, classification error (model 2): 0.383778543731
# Validation data, classification error (model 3): 0.380008616975

# %% [markdown]
# **Quiz Question:** Which tree has the smallest error on the validation data?

# %% [markdown]
# **Quiz Reponse:** model 3

# %% [markdown]
# **Quiz Question:** Does the tree with the smallest error in the training data also have the smallest error in the validation data?

# %% [markdown]
# **Quiz Reponse:** Yes

# %% [markdown]
# **Quiz Question:** Is it always true that the tree with the lowest classification error on the **training** set will result in the lowest classification error in the **validation** set?

# %% [markdown]
# **Quiz Response**: No

# %% [markdown]
# ### Measuring the complexity of the tree
#
# Recall in the lecture that we talked about deeper trees being more complex. We will measure the complexity of the tree as
#
# ```
#   complexity(T) = number of leaves in the tree T
# ```
#
# Here, we provide a function `count_leaves` that counts the number of leaves in a tree. Using this implementation, compute the number of nodes in `model_1`, `model_2`, and `model_3`.

# %%
def count_leaves(tree):
    if tree["is_leaf"]:
        return 1
    return count_leaves(tree["left"]) + count_leaves(tree["right"])

# %% [markdown]
# Compute the number of nodes in `model_1`, `model_2`, and `model_3`.

# %%
print("Complexity model_1 (nb leaves):",count_leaves(model_1))
print("Complexity model_2 (nb leaves):",count_leaves(model_2))
print("Complexity model_3 (nb leaves):",count_leaves(model_3))
# Out:
# Complexity model_1 (nb leaves): 4
# Complexity model_2 (nb leaves): 41
# Complexity model_3 (nb leaves): 341

# %% [markdown]
# **Quiz Question:** Which tree has the largest complexity?

# %% [markdown]
# **Quiz Response:** model_3

# %% [markdown]
# **Quiz Question:** Is it always true that the most complex tree will result in the lowest classification error in the **validation_set**?

# %% [markdown]
# **Quiz Response:** No

# %% [markdown]
# # Exploring the effect of min_error
#
# We will compare three models trained with different values of the stopping criterion. We intentionally picked models at the extreme ends (**negative**, **just right**, and **too positive**).
#
# Train three models with these parameters:
# 1. **model_4**: `min_error_reduction = -1` (ignoring this early stopping condition)
# 2. **model_5**: `min_error_reduction = 0` (just right)
# 3. **model_6**: `min_error_reduction = 5` (too positive)
#
# For each of these three, we set `max_depth = 6`, and `min_node_size = 0`.
#
# ** Note:** Each tree can take up to 30 seconds to train.

# %%
model_4 = decision_tree_create(train_data, features, "safe_loans", max_depth = 6,
                               min_node_size = 0, min_error_reduction=-1)
model_5 = decision_tree_create(train_data, features, "safe_loans", max_depth = 6,
                               min_node_size = 0, min_error_reduction=0)
model_6 = decision_tree_create(train_data, features, "safe_loans", max_depth = 6,
                               min_node_size = 0, min_error_reduction=5)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 with 37224 data points
# Split on feature term. 36 months left split size: 9223 right split size: 28001
# --------------------------------------------------------------------
# Subtree, depth = 1 with 9223 data points
# Split on feature grade.A left split size: 9122 right split size: 101
# --------------------------------------------------------------------
# Subtree, depth = 2 with 9122 data points
# Split on feature grade.B left split size: 8074 right split size: 1048
# --------------------------------------------------------------------
# Subtree, depth = 3 with 8074 data points
# Split on feature grade.C left split size: 5884 right split size: 2190
# --------------------------------------------------------------------
# Subtree, depth = 4 with 5884 data points
# Split on feature grade.D left split size: 3826 right split size: 2058
# --------------------------------------------------------------------
# Subtree, depth = 5 with 3826 data points
# Split on feature grade.E left split size: 1693 right split size: 2133
# --------------------------------------------------------------------
# Subtree, depth = 6 with 1693 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2133 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 2058 data points
# Split on feature grade.E left split size: 2058 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2058 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 2190 data points
# Split on feature grade.D left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 2190 data points
# Split on feature grade.E left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2190 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1048 data points
# Split on feature emp_length.5 years left split size: 969 right split size: 79
# --------------------------------------------------------------------
# Subtree, depth = 4 with 969 data points
# Split on feature grade.C left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 969 data points
# Split on feature grade.D left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 969 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 79 data points
# Split on feature home_ownership.MORTGAGE left split size: 34 right split size: 45
# --------------------------------------------------------------------
# Subtree, depth = 5 with 34 data points
# Split on feature grade.C left split size: 34 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 34 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 45 data points
# Split on feature grade.C left split size: 45 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 45 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 101 data points
# Split on feature emp_length.n/a left split size: 96 right split size: 5
# --------------------------------------------------------------------
# Subtree, depth = 3 with 96 data points
# Split on feature emp_length.< 1 year left split size: 85 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 4 with 85 data points
# Split on feature grade.B left split size: 85 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 85 data points
# Split on feature grade.C left split size: 85 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 85 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 11 data points
# Split on feature grade.B left split size: 11 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 11 data points
# Split on feature grade.C left split size: 11 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 11 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 5 data points
# Split on feature grade.B left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 5 data points
# Split on feature grade.C left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 5 data points
# Split on feature grade.D left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 5 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 1 with 28001 data points
# Split on feature grade.D left split size: 23300 right split size: 4701
# --------------------------------------------------------------------
# Subtree, depth = 2 with 23300 data points
# Split on feature grade.E left split size: 22024 right split size: 1276
# --------------------------------------------------------------------
# Subtree, depth = 3 with 22024 data points
# Split on feature grade.F left split size: 21666 right split size: 358
# --------------------------------------------------------------------
# Subtree, depth = 4 with 21666 data points
# Split on feature emp_length.n/a left split size: 20734 right split size: 932
# --------------------------------------------------------------------
# Subtree, depth = 5 with 20734 data points
# Split on feature grade.G left split size: 20638 right split size: 96
# --------------------------------------------------------------------
# Subtree, depth = 6 with 20638 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 96 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 932 data points
# Split on feature grade.A left split size: 702 right split size: 230
# --------------------------------------------------------------------
# Subtree, depth = 6 with 702 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 230 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 358 data points
# Split on feature emp_length.8 years left split size: 347 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 5 with 347 data points
# Split on feature grade.A left split size: 347 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 347 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 11 data points
# Split on feature home_ownership.OWN left split size: 9 right split size: 2
# --------------------------------------------------------------------
# Subtree, depth = 6 with 9 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1276 data points
# Split on feature grade.A left split size: 1276 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 1276 data points
# Split on feature grade.B left split size: 1276 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 1276 data points
# Split on feature grade.C left split size: 1276 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 1276 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 4701 data points
# Split on feature grade.A left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 3 with 4701 data points
# Split on feature grade.B left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 4701 data points
# Split on feature grade.C left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 4701 data points
# Split on feature grade.E left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 4701 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 0 with 37224 data points
# Split on feature term. 36 months left split size: 9223 right split size: 28001
# --------------------------------------------------------------------
# Subtree, depth = 1 with 9223 data points
# Split on feature grade.A left split size: 9122 right split size: 101
# --------------------------------------------------------------------
# Subtree, depth = 2 with 9122 data points
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 101 data points
# Split on feature emp_length.n/a left split size: 96 right split size: 5
# --------------------------------------------------------------------
# Subtree, depth = 3 with 96 data points
# Split on feature emp_length.< 1 year left split size: 85 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 4 with 85 data points
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 11 data points
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 5 data points
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 1 with 28001 data points
# Split on feature grade.D left split size: 23300 right split size: 4701
# --------------------------------------------------------------------
# Subtree, depth = 2 with 23300 data points
# Split on feature grade.E left split size: 22024 right split size: 1276
# --------------------------------------------------------------------
# Subtree, depth = 3 with 22024 data points
# Split on feature grade.F left split size: 21666 right split size: 358
# --------------------------------------------------------------------
# Subtree, depth = 4 with 21666 data points
# Split on feature emp_length.n/a left split size: 20734 right split size: 932
# --------------------------------------------------------------------
# Subtree, depth = 5 with 20734 data points
# Split on feature grade.G left split size: 20638 right split size: 96
# --------------------------------------------------------------------
# Subtree, depth = 6 with 20638 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 96 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 932 data points
# Split on feature grade.A left split size: 702 right split size: 230
# --------------------------------------------------------------------
# Subtree, depth = 6 with 702 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 230 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 358 data points
# Split on feature emp_length.8 years left split size: 347 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 5 with 347 data points
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 11 data points
# Split on feature home_ownership.OWN left split size: 9 right split size: 2
# --------------------------------------------------------------------
# Subtree, depth = 6 with 9 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1276 data points
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 4701 data points
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 0 with 37224 data points
# Early stopping condition 3 reached. Minimum error reduction.

# %% [markdown]
# Calculate the accuracy of each model (**model_4**, **model_5**, or **model_6**) on the validation set.

# %%
print("Validation data, classification error (model 4):", evaluate_classification_error(model_4, validation_set, target))
print("Validation data, classification error (model 5):", evaluate_classification_error(model_5, validation_set, target))
print("Validation data, classification error (model 6):", evaluate_classification_error(model_6, validation_set, target))
# Out:
# Validation data, classification error (model 4): 0.383778543731
# Validation data, classification error (model 5): 0.383778543731
# Validation data, classification error (model 6): 0.503446790177

# %% [markdown]
# Using the `count_leaves` function, compute the number of leaves in each of each models in (**model_4**, **model_5**, and **model_6**).

# %%
print("Complexity model_4 (nb leaves):",count_leaves(model_4))
print("Complexity model_5 (nb leaves):",count_leaves(model_5))
print("Complexity model_6 (nb leaves):",count_leaves(model_6))
# Out:
# Complexity model_4 (nb leaves): 41
# Complexity model_5 (nb leaves): 13
# Complexity model_6 (nb leaves): 1

# %% [markdown]
# **Quiz Question:** Using the complexity definition above, which model (**model_4**, **model_5**, or **model_6**) has the largest complexity?
#
# Did this match your expectation?

# %% [markdown]
# **Quiz Response:** model_4

# %% [markdown]
# **Quiz Question:** **model_4** and **model_5** have similar classification error on the validation set but **model_5** has lower complexity. Should you pick **model_5** over **model_4**?

# %% [markdown]
# **Quiz Response:** model_5

# %% [markdown]
# # Exploring the effect of min_node_size
#
# We will compare three models trained with different values of the stopping criterion. Again, intentionally picked models at the extreme ends (**too small**, **just right**, and **just right**).
#
# Train three models with these parameters:
# 1. **model_7**: min_node_size = 0 (too small)
# 2. **model_8**: min_node_size = 2000 (just right)
# 3. **model_9**: min_node_size = 50000 (too large)
#
# For each of these three, we set `max_depth = 6`, and `min_error_reduction = -1`.
#
# ** Note:** Each tree can take up to 30 seconds to train.

# %%
model_7 = decision_tree_create(train_data, features, "safe_loans", max_depth = 6,
                               min_node_size = 0, min_error_reduction=-1)
model_8 = decision_tree_create(train_data, features, "safe_loans", max_depth = 6,
                               min_node_size = 2000, min_error_reduction=-1)
model_9 = decision_tree_create(train_data, features, "safe_loans", max_depth = 6,
                               min_node_size = 50000, min_error_reduction=-1)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 with 37224 data points
# Split on feature term. 36 months left split size: 9223 right split size: 28001
# --------------------------------------------------------------------
# Subtree, depth = 1 with 9223 data points
# Split on feature grade.A left split size: 9122 right split size: 101
# --------------------------------------------------------------------
# Subtree, depth = 2 with 9122 data points
# Split on feature grade.B left split size: 8074 right split size: 1048
# --------------------------------------------------------------------
# Subtree, depth = 3 with 8074 data points
# Split on feature grade.C left split size: 5884 right split size: 2190
# --------------------------------------------------------------------
# Subtree, depth = 4 with 5884 data points
# Split on feature grade.D left split size: 3826 right split size: 2058
# --------------------------------------------------------------------
# Subtree, depth = 5 with 3826 data points
# Split on feature grade.E left split size: 1693 right split size: 2133
# --------------------------------------------------------------------
# Subtree, depth = 6 with 1693 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2133 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 2058 data points
# Split on feature grade.E left split size: 2058 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2058 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 2190 data points
# Split on feature grade.D left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 2190 data points
# Split on feature grade.E left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2190 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1048 data points
# Split on feature emp_length.5 years left split size: 969 right split size: 79
# --------------------------------------------------------------------
# Subtree, depth = 4 with 969 data points
# Split on feature grade.C left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 969 data points
# Split on feature grade.D left split size: 969 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 969 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 79 data points
# Split on feature home_ownership.MORTGAGE left split size: 34 right split size: 45
# --------------------------------------------------------------------
# Subtree, depth = 5 with 34 data points
# Split on feature grade.C left split size: 34 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 34 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 45 data points
# Split on feature grade.C left split size: 45 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 45 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 101 data points
# Split on feature emp_length.n/a left split size: 96 right split size: 5
# --------------------------------------------------------------------
# Subtree, depth = 3 with 96 data points
# Split on feature emp_length.< 1 year left split size: 85 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 4 with 85 data points
# Split on feature grade.B left split size: 85 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 85 data points
# Split on feature grade.C left split size: 85 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 85 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 11 data points
# Split on feature grade.B left split size: 11 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 11 data points
# Split on feature grade.C left split size: 11 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 11 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 5 data points
# Split on feature grade.B left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 5 data points
# Split on feature grade.C left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 5 data points
# Split on feature grade.D left split size: 5 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 5 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 1 with 28001 data points
# Split on feature grade.D left split size: 23300 right split size: 4701
# --------------------------------------------------------------------
# Subtree, depth = 2 with 23300 data points
# Split on feature grade.E left split size: 22024 right split size: 1276
# --------------------------------------------------------------------
# Subtree, depth = 3 with 22024 data points
# Split on feature grade.F left split size: 21666 right split size: 358
# --------------------------------------------------------------------
# Subtree, depth = 4 with 21666 data points
# Split on feature emp_length.n/a left split size: 20734 right split size: 932
# --------------------------------------------------------------------
# Subtree, depth = 5 with 20734 data points
# Split on feature grade.G left split size: 20638 right split size: 96
# --------------------------------------------------------------------
# Subtree, depth = 6 with 20638 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 96 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 932 data points
# Split on feature grade.A left split size: 702 right split size: 230
# --------------------------------------------------------------------
# Subtree, depth = 6 with 702 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 230 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 358 data points
# Split on feature emp_length.8 years left split size: 347 right split size: 11
# --------------------------------------------------------------------
# Subtree, depth = 5 with 347 data points
# Split on feature grade.A left split size: 347 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 347 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 11 data points
# Split on feature home_ownership.OWN left split size: 9 right split size: 2
# --------------------------------------------------------------------
# Subtree, depth = 6 with 9 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1276 data points
# Split on feature grade.A left split size: 1276 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 1276 data points
# Split on feature grade.B left split size: 1276 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 1276 data points
# Split on feature grade.C left split size: 1276 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 1276 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 4701 data points
# Split on feature grade.A left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 3 with 4701 data points
# Split on feature grade.B left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 4701 data points
# Split on feature grade.C left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 4701 data points
# Split on feature grade.E left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 4701 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 0 with 37224 data points
# Split on feature term. 36 months left split size: 9223 right split size: 28001
# --------------------------------------------------------------------
# Subtree, depth = 1 with 9223 data points
# Split on feature grade.A left split size: 9122 right split size: 101
# --------------------------------------------------------------------
# Subtree, depth = 2 with 9122 data points
# Split on feature grade.B left split size: 8074 right split size: 1048
# --------------------------------------------------------------------
# Subtree, depth = 3 with 8074 data points
# Split on feature grade.C left split size: 5884 right split size: 2190
# --------------------------------------------------------------------
# Subtree, depth = 4 with 5884 data points
# Split on feature grade.D left split size: 3826 right split size: 2058
# --------------------------------------------------------------------
# Subtree, depth = 5 with 3826 data points
# Split on feature grade.E left split size: 1693 right split size: 2133
# --------------------------------------------------------------------
# Subtree, depth = 6 with 1693 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2133 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 2058 data points
# Split on feature grade.E left split size: 2058 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2058 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 2190 data points
# Split on feature grade.D left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 2190 data points
# Split on feature grade.E left split size: 2190 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 2190 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1048 data points
# Early stopping condition 2 reached. Reached minimum node size.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 101 data points
# Early stopping condition 2 reached. Reached minimum node size.
# --------------------------------------------------------------------
# Subtree, depth = 1 with 28001 data points
# Split on feature grade.D left split size: 23300 right split size: 4701
# --------------------------------------------------------------------
# Subtree, depth = 2 with 23300 data points
# Split on feature grade.E left split size: 22024 right split size: 1276
# --------------------------------------------------------------------
# Subtree, depth = 3 with 22024 data points
# Split on feature grade.F left split size: 21666 right split size: 358
# --------------------------------------------------------------------
# Subtree, depth = 4 with 21666 data points
# Split on feature emp_length.n/a left split size: 20734 right split size: 932
# --------------------------------------------------------------------
# Subtree, depth = 5 with 20734 data points
# Split on feature grade.G left split size: 20638 right split size: 96
# --------------------------------------------------------------------
# Subtree, depth = 6 with 20638 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 96 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 932 data points
# Early stopping condition 2 reached. Reached minimum node size.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 358 data points
# Early stopping condition 2 reached. Reached minimum node size.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 1276 data points
# Early stopping condition 2 reached. Reached minimum node size.
# --------------------------------------------------------------------
# Subtree, depth = 2 with 4701 data points
# Split on feature grade.A left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 3 with 4701 data points
# Split on feature grade.B left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 4 with 4701 data points
# Split on feature grade.C left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 5 with 4701 data points
# Split on feature grade.E left split size: 4701 right split size: 0
# --------------------------------------------------------------------
# Subtree, depth = 6 with 4701 data points
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 6 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 5 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 4 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 3 with 0 data points
# Stopping condition 1 reached. All data points have the same target value.
# --------------------------------------------------------------------
# Subtree, depth = 0 with 37224 data points
# Early stopping condition 2 reached. Reached minimum node size.

# %% [markdown]
# Now, let us evaluate the models (**model_7**, **model_8**, or **model_9**) on the **validation_set**.

# %%
print("Validation data, classification error (model 7):", evaluate_classification_error(model_7, validation_set, target))
print("Validation data, classification error (model 8):", evaluate_classification_error(model_8, validation_set, target))
print("Validation data, classification error (model 9):", evaluate_classification_error(model_9, validation_set, target))
# Out:
# Validation data, classification error (model 7): 0.383778543731
# Validation data, classification error (model 8): 0.384532529082
# Validation data, classification error (model 9): 0.503446790177

# %% [markdown]
# Using the `count_leaves` function, compute the number of leaves in each of each models (**model_7**, **model_8**, and **model_9**).

# %%
print("Complexity model_7 (nb leaves):",count_leaves(model_7))
print("Complexity model_8 (nb leaves):",count_leaves(model_8))
print("Complexity model_9 (nb leaves):",count_leaves(model_9))
# Out:
# Complexity model_7 (nb leaves): 41
# Complexity model_8 (nb leaves): 19
# Complexity model_9 (nb leaves): 1

# %% [markdown]
# **Quiz Question:** Using the results obtained in this section, which model (**model_7**, **model_8**, or **model_9**) would you choose to use?

# %% [markdown]
# **Quiz Response:** model_8
